# %% [markdown]
# <a href="https://colab.research.google.com/github/gorrografico7/metodos_numericos/blob/main/Tomas_Correa_Zea_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Operaciones Básicas**

# %%
8*9
# Out:
# 72

# %%
81/27
# Out:
# 3.0

# %%
9+5
# Out:
# 14

# %%
8-5
# Out:
# 3

# %% [markdown]
# **Números complejos**

# %%
a=3+4j
b=5+9j
a
# Out:
# (3+4j)

# %%
print(a)
# Out:
# (3+4j)

# %% [markdown]
# **Valor Absoluto**

# %%
abs(5-9)
# Out:
# 4

# %% [markdown]
# **Función parte entera en una división**

# %%
9//2
# Out:
# 4

# %% [markdown]
# **Función residuo**

# %%
9%2
# Out:
# 1

# %% [markdown]
# **Asignación de variables**

# %%
x,y=5,6

# %%
print(x,y)
# Out:
# 5 6

# %%
print(y)
# Out:
# 6

# %% [markdown]
# **Tipos de datos**

# %%
b=5.34
b
# Out:
# 5.34

# %%
a=77
a
# Out:
# 77

# %%
z="Juanito"
z
# Out:
# 'Juanito'

# %% [markdown]
# **Operadores de comparación**

# %%
x==y
# Out:
# False

# %%
x,y=2,5

# %%
print(x>y)
print(x<=y)
print(x!=y)
print(x<y)
print(x>=y)
# Out:
# False
# True
# True
# True
# False

# %% [markdown]
# **Condicionales**

# %%
x=1890
if x%7==0:
  print("x es multiplo de 7")
else:
  print("x no es multiplo de 7")
# Out:
# x es multiplo de 7

# %%
if x<y:
  print("x es mayor que y")
elif x>y:
  print("x es menor que y")
else:
  print("x es igual a y")
# Out:
# x es mayor que y
