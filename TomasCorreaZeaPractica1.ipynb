# %% [markdown]
# <a href="https://colab.research.google.com/github/gorrografico7/metodos_numericos/blob/main/TomasCorreaZeaPractica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctica 1: Introducción a Python

# %%
8*9

# %%
81/27

# %%
8-5

# %%
9+5

# %% [markdown]
# ## Números Complejos

# %%
a = 3+4j
b = 5+9j
a

# %%
print(a)

# %% [markdown]
# ## Función parte entera

# %%
9//2

# %% [markdown]
# ## Función residuo

# %%
9%2

# %% [markdown]
# ## Valor absoluto

# %%
abs(5-9)

# %% [markdown]
# ## Asignación de variables

# %%
x, y = 5, 6
print(y)
print(y, x)

# %% [markdown]
# ## Tipos de datos

# %%
z = 'juanito'
z

# %%
b = 5.34
b

# %%
a = 77
a

# %% [markdown]
# ## Operadores de comparación

# %%
x, y = 2, 5
x == y

# %%
print(x>y)
print(x<=y)
print(x!=y)
print(x<y)
print(x>=y)

# %% [markdown]
# ## Condicionales

# %%
if x > y:
    print('x es mayor que y')
elif x < y:
    print('x es menor que y')
else:
    print('x es igual a y')

# %%
x = 1890
if x % 7 == 0:
    print('x es multiplo de 7')
else:
    print('x no es multiplo de 7')
